# %% [markdown]
# <h1>Introduction</h1>
# <p>In these lab notes we will introduce you to Naïve Bayes and your task is to implement a relatively simple spam filter.  We will use a small data set to train and test the model (available on Blackboard). </p>
#
# <b>Note:</b>  Use Jupyter Notebook or Google Colab (NOT Jupyter Lab).
#
# <p>The messages within the datasets have already been classified as spam, or ham (not spam). </p>
#
# <p>The implementation of a Naïve Bayes Spam Filter is relatively straight forward using scikit-learn, however, this library hides the implementation details (and many solutions are available on the Internet).  Therefore, this task does not permit the use of the scikit-learn library or similar libraries that perform similar tasks.  We hope that this will help with your understanding of the implementation details.</p>
# <p>Bayes Theorem can give us the probability that a message is spam S for a given event E</p>
#
# <h1>
# $P\left(S\middle|\ E\right)=\frac{P\left(E\middle|\ S\right)P\left(S\right)}{P\left(E\middle|\ S\right)P\left(S\right)+P\left(E|\lnot S\right)P\left(\lnot S\right)}$
# </h1>
#
# <p>Where:</p>
# <p>$P\left(S\middle|\ E\right)$, the probability that the message is spam given the event occurred.</p>
# <p>$P\left(S\right)$, the prior probability that a message is spam.</p>
# <p>$P\left(\lnot S\right)$, the prior probability that a message is not spam.  </p>
#
# Note:  $P\left(S\right)$ and $P\left(\lnot S\right)$ are prior values, or prior beliefs.  This value could be calculated using the number of spam and number of ham classifications in the data set.  You could also use arbitrary values, for example; you could assume that of all email messages sent, 80% of them are spam and 20% of them are not spam.  The success of the filter depends on the prior values.
#
# <p>$P\left(E\middle|\ S\right)$, the probability that event E occurs in a spam emails.</p>
#
# <p>$P\left(E|\lnot S\right)$, the probability that event E occurs in non-spam emails.</p>
#
# <h3>Additional Libraries</h3>
# <p>As you progress through the exercises you may need additional libraries that are not installed, for example when visualising the data you may need to import WordCloud.  If you use [Google Colaboratory](https://colab.research.google.com/notebooks/intro.ipynb) the necessary libraries will be available, which will save you having to pip install.  </p>
# <h3>The Implementation</h3>
# <p>We have tried to keep the implementation quite simple and therefore not accounted for things like filtering small often used words, nor does the implementation calculate probabilities of a word in the frequency list not appearing in spam.  We have also filtered things like telephone numbers, which could be used to identify spam.   The final exercise allows you to make recommendations how the model could be improved.    </p>

# %%
# Had issues using Google Colaboratory
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\thund\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\thund\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\thund\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\thund\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thund\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\thund\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h3>1.  Read the dataset into a dataframe and explore</h3>
# <p>Start by importing pandas and read the dataset into a DataFrame named df.  Output the first 20 rows of the dataframe to get a general feel of how the data is structured.</p>
# <p>You may encounter the error: UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 135-136: invalid continuation byte.  You don't need to edit the datafile,  as you should be able to successfully read in the datafile by changing the encoding to latin-1.</p>
# <p>[1 Mark]</p>

# %%
import pandas as pd
df = pd.read_csv('spam.csv', encoding='latin-1')
df = df[['v1', 'v2']]
df.head(20)
# Out:
#       v1                                                 v2
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...
# 6    ham  Even my brother is not like to speak with me. ...
# 7    ham  As per your request 'Melle Melle (Oru Minnamin...
# 8   spam  WINNER!! As a valued network customer you have...
# 9   spam  Had your mobile 11 months or more? U R entitle...
# 10   ham  I'm gonna be home soon and i don't want to tal...
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...
# 12  spam  URGENT! You have won a 1 week FREE membership ...
# 13   ham  I've been searching for the right words to tha...
# 14   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
# 15  spam  XXXMobileMovieClub: To use your credit, click ...
# 16   ham                         Oh k...i'm watching here:)
# 17   ham  Eh u remember how 2 spell his name... Yes i di...
# 18   ham  Fine if thatåÕs the way u feel. ThatåÕs the wa...
# 19  spam  England v Macedonia - dont miss the goals/team...

# %% [markdown]
# <h3>2. Clean the data</h3>
# <p>We are only interested in words, clean the data so that all punctuations are removed.  You should be left with a dataset that only contains alpha characters (including spaces).  You should also ensure all the words are lowercase.  Store the cleaned data into a DataFrame named clean.</p>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ham</td>
#       <td>go until jurong point crazy available only in ...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ham</td>
#       <td>ok lar joking wif u oni</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>spam</td>
#       <td>free entry in  a wkly comp to win fa cup final...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ham</td>
#       <td>u dun say so early hor u c already then say</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ham</td>
#       <td>nah i dont think he goes to usf he lives aroun...</td>
#     </tr>
#   </tbody>
# </table>
#
# [1 Marks]

# %%
# dataframe called clean
clean = df.copy()

# rename columns as in example
clean.rename(columns={'v1': 'Category', 'v2': 'Message'}, inplace=True)

# lowercasing category and message columns
clean['Category'] = clean['Category'].str.lower()
clean['Message'] = clean['Message'].str.lower()

# removing non-alphabet characters from category and message columns
clean['Category'] = clean['Category'].apply(lambda x: ''.join(c for c in x if c.isalpha()))
clean['Message'] = clean['Message'].apply(lambda x: ''.join(c for c in x if c.isalpha() or c.isspace()))

clean.head(20)
# Out:
#    Category                                            Message
# 0       ham  go until jurong point crazy available only in ...
# 1       ham                            ok lar joking wif u oni
# 2      spam  free entry in  a wkly comp to win fa cup final...
# 3       ham        u dun say so early hor u c already then say
# 4       ham  nah i dont think he goes to usf he lives aroun...
# 5      spam  freemsg hey there darling its been  weeks now ...
# 6       ham  even my brother is not like to speak with me t...
# 7       ham  as per your request melle melle oru minnaminun...
# 8      spam  winner as a valued network customer you have b...
# 9      spam  had your mobile  months or more u r entitled t...
# 10      ham  im gonna be home soon and i dont want to talk ...
# 11     spam  six chances to win cash from  to  pounds txt c...
# 12     spam  urgent you have won a  week free membership in...
# 13      ham  ive been searching for the right words to than...
# 14      ham                  i have a date on sunday with will
# 15     spam  xxxmobilemovieclub to use your credit click th...
# 16      ham                               oh kim watching here
# 17      ham  eh u remember how  spell his name yes i did he...
# 18      ham  fine if thatåõs the way u feel thatåõs the way...
# 19     spam  england v macedonia  dont miss the goalsteam n...

# %% [markdown]
# <h3>3. Split the Data</h3>
# <p>Split the data into three random samples, one for training the model, one for validation and the other for testing the model.  Create DataFrames named train_data, validation_data and test_data.  The train_data DataFrame should contain 60-70% of the data, validation_data 15-20% and the test_data DataFrame the remaining data.<p>
#
# <p>[1 Mark]</p>

# %%
from sklearn.model_selection import train_test_split

train_data_temp, test_data = train_test_split(clean, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)
train_data = train_data_temp.reset_index(drop=True)

# %% [markdown]
# <h3>4. Create a Word Frequency DataFrame</h3>
# <p>Create a new DataFrame named word_freq that contains each word with the number of times it appears in a spam and a ham message.  You should use the train_data.</p>
# <p>Below is an example of what the DataFrame would look like, <i>note</i> that your values may differ depending on how the data was split.</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Word</th>
#       <th>#Spam</th>
#       <th>#Ham</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>go</td>
#       <td>27</td>
#       <td>196</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>until</td>
#       <td>4</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>jurong</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>point</td>
#       <td>1</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>crazy</td>
#       <td>4</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>7253</td>
#       <td>salesman</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>7254</td>
#       <td>pity</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>7255</td>
#       <td>soany</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>7256</td>
#       <td>suggestions</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>7257</td>
#       <td>bitching</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>[2 Marks]</p>

# %%
from collections import Counter

spam_messages = train_data[train_data['Category'] == 'spam']['Message']
ham_messages = train_data[train_data['Category'] == 'ham']['Message']
spam_words = ' '.join(spam_messages).split()
ham_words = ' '.join(ham_messages).split()

spam_word_counts = Counter(spam_words)
ham_word_counts = Counter(ham_words)

word_freq_df = pd.DataFrame({'Word': list(set(spam_words + ham_words)),
                          '#Spam': [spam_word_counts[word] for word in set(spam_words + ham_words)],
                          '#Ham': [ham_word_counts[word] for word in set(spam_words + ham_words)]})

word_freq_df = word_freq_df[['Word', '#Spam', '#Ham']]

word_freq_df.head(20)
# Out:
#                      Word  #Spam  #Ham
# 0            thanksgiving      0     3
# 1            appointments      0     1
# 2                  lennon      0     1
# 3                     bet      0     2
# 4                 satisfy      1     0
# 5                     åea      1     0
# 6                   redim      0     1
# 7   achanammarakheshqatar      0     1
# 8                pdatenow      1     0
# 9                   aiyah      0     1
# 10                    soo      0     2
# 11                   wrks      0     1
# 12               honeydid      0     1
# 13                  dolld      0     1
# 14               goodmate      0     1
# 15                   maps      0     1
# 16                     us      7    33
# 17          mobilesdirect      3     0
# 18               schedule      0     1
# 19                   godi      0     2

# %% [markdown]
# <h3>5. Visualise the Data</h3>
# <p>Let's use a Word Cloud library to visualise the most common words contained in spam messages.</p>
#
# [Example of a Word Cloud Image](https://drive.google.com/open?id=1lVRGHtMB1AMJf-JSi7MmcHbZB_BvBhGC)
#
# <p>[1 Marks]</p>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# most common words
most_common_spam_words = word_freq_df[word_freq_df['#Spam'] > 0].sort_values(by='#Spam', ascending=False)

# dictionary of word frequencies for word cloud
spam_wordcloud_dictionary = {word: freq for word, freq in zip(most_common_spam_words['Word'], most_common_spam_words['#Spam'])}

# create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(spam_wordcloud_dictionary)

# plotting word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words Contained in Spam Messages')
plt.show()

# %% [markdown]
# <h3>6.  Calculate $P\left(E\middle| S\right)$ and $P\left(E|\lnot S\right)$</h3>
# <p>Next create a new DataFrame named word_prob that gives the probability of each word being found in a spam and ham message.</p>
# <p>To calculate the probability of a word being spam you divide the number of times the word was found in spam by the total number of spam messages, likewise to calculate the probability of each word being found in a ham message you divide the number of times the word was found in a ham message by the total number of ham messages.</p>
# <p>If a word was not found in ham or spam it will cause problems later because the probability calculated will be zero. Therefore, use a pseudocount k and estimate the probability of seeing the word. This is known as smoothing and results in the following formula when k = 0.5, for example.</p>
# <p>$P\left(E\middle| S\right)$ = (number of spams containing the word + k) / (total number of spam messages + 2 * k).</p>
# <p>Likewise, for $P\left(E|\lnot S\right)$.</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Word</th>
#       <th>P(E|S)</th>
#       <th>P(E|¬S)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>go</td>
#       <td>0.053322</td>
#       <td>0.050055</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>until</td>
#       <td>0.011364</td>
#       <td>0.004275</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>jurong</td>
#       <td>0.002622</td>
#       <td>0.000138</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>point</td>
#       <td>0.002622</td>
#       <td>0.002344</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>crazy</td>
#       <td>0.011364</td>
#       <td>0.002344</td>
#     </tr>
#   </tbody>
# </table>
# </p>[2 Marks]</p>

# %%
# pseudocount k
k = 0.5

total_spam_messages = train_data[train_data['Category'] == 'spam'].shape[0]
total_ham_messages = train_data[train_data['Category'] == 'ham'].shape[0]

# new dataframe word_prob
word_prob = pd.DataFrame({'Word': word_freq_df['Word'],
                          'P(E|S)': (word_freq_df['#Spam'] + k) / (total_spam_messages + 2 * k),
                          'P(E|¬S)': (word_freq_df['#Ham'] + k) / (total_ham_messages + 2 * k)})

# %% [markdown]
# <h3>7. Checking the 'spamliness' of a single word</h3>
# <p>Now that we have trained the model, we will test the model.  Before we use the test_data, first let’s check how the model calculates the spamliness of a single word.  This is where we use the Bayes Theorem formula.  We have already calculated $P\left(E\middle| S\right)$ and $P\left(E|\lnot S\right)$, so we can just extract these values from the word_prob DataFrame.</p>
# <p>We need to decide on the prior values $P\left(S\right)$ and $P\left(\lnot S\right)$, this is where you can experiment and tweak the model, in this example the prior value for spam was set to $0.4$ and the prior value for not spam or ham was set to $0.6$.</p>
# <h3>
# $P\left(S\middle|\ E\right)=\frac{P\left(E\middle|\ S\right)P\left(S\right)}{P\left(E\middle|\ S\right)P\left(S\right)+P\left(E|\lnot S\right)P\left(\lnot S\right)}$
# </h3>
# <pre>
# Output
# Word = ['free']
# P(E|S) = [0.29108392]
# P(E|¬S) = [0.01365141]
# P(S|E) = [0.93427577]
# P(¬S|E) = [0.06572423]
# </pre>
#
# <p>[2 Marks]</p>

# %%
word = 'free'
P_E_given_S = word_prob.loc[word_prob['Word'] == word, 'P(E|S)'].values[0]
P_E_given_not_S = word_prob.loc[word_prob['Word'] == word, 'P(E|¬S)'].values[0]

P_S = 0.4
P_not_S = 0.6

# calculations
P_S_given_E = (P_E_given_S * P_S) / (P_E_given_S * P_S + P_E_given_not_S * P_not_S)
P_not_S_given_E = 1 - P_S_given_E

# output results
print("Output")
print("Word = ['" + word + "']")
print("P(E|S) =", P_E_given_S)
print("P(E|¬S) =", P_E_given_not_S)
print("P(S|E) =", P_S_given_E)
print("P(¬S|E) =", P_not_S_given_E)
# Out:
# Output
# Word = ['free']
# P(E|S) = 0.3052930056710775
# P(E|¬S) = 0.012896531277794249
# P(S|E) = 0.9404111389293263
# P(¬S|E) = 0.05958886107067374

# %% [markdown]
# <h3>8. Checking the 'spamliness' of several words</h3>
# <p>To check the spamliness of several words contained in a message we multiply the probabilities.  The model assumes the words appear as independent events hence the naïve Bayes.  In reality of course, words are not independent events, but the model still performs well.  So we use the assumption that the words appear independently, and hence we multiply probabilities, so
# $P(S\,|\, x_1,\dots,x_n)\approx \frac{P(S)\underset{i=1}{\overset{n}{\prod}}P(x_i | S)}{P(S)\underset{i=1}{\overset{n}{\prod}}P(x_i | S)+P(\neg S)\underset{i=1}{\overset{n}{\prod}}P(x_i | \neg S)}$
#
# Calculate the probability for each word in a message being spam, you might want to store the calculations in a list named prob_spam.  Likewise create a list for each word not being spam.
# Then multiply the probabilities and compare the results.  If the result of multiplying the probabilities for spam is greater than the result of multiplying the probabilities for not spam, then you assume the message as spam.
# </p>
# <p>If you have a word in your message that is not in the word_prob DataFrame then you can't get the probability.  Skip any words in the message that are not in the word_prob DataFrame.</p>
# <p>[2 Marks]</p>

# %%
import numpy as np
# using one of the first 20 messages
message = "i have a date on sunday with will"

# storing calculations
prob_spam = []
prob_not_spam = []

words_of_message = message.split()

# loop through message
for word in words_of_message:
    # check if word is in word_prob
    if word in word_prob['Word'].values:
        P_E_given_S = word_prob.loc[word_prob['Word'] == word, 'P(E|S)'].values[0]
        P_E_given_not_S = word_prob.loc[word_prob['Word'] == word, 'P(E|¬S)'].values[0]
        
        # calc probabilities
        prob_spam.append(P_E_given_S)
        prob_not_spam.append(P_E_given_not_S)
        
    else:
        continue
        
# final calculations for spam and not spam
prod_prob_spam = P_S * np.prod(prob_spam)
prod_prob_not_spam = P_not_S * np.prod(prob_not_spam)

# print results
if prod_prob_spam > prod_prob_not_spam:
    print("The message is assummed to be spam.")
else:
    print("The message is not assumed to be spam.")
# Out:
# The message is assummed to be spam.

# %% [markdown]
# <h3>9. Avoiding floating point underflow</h3>
# <p>Our aim is to compare two probabilities $P(S|x_1,\dots,x_n)$ with $P(\neg S|x_1,\dots,x_n),$ according to our model introduced in Section 8, both probabilities share a common denominator which does not affect comparison. Hence we will calculate numerators only, which are proportional to $P(S|x_1,\dots,x_n)$ and $P(\neg S|x_1,\dots,x_n).$
# </p>
#
# <p>Multiplying a set of small probabilities could result in a floating-point error.  This is where the product becomes too small to be represented correctly.  To avoid this we can take the logarithm of the probabilities and add them.
#
# To avoid multiplication of small numbers, we use the following property of $\log(x):$</p>
# $$
# \log(a\cdot b)=\log(a)+\log(b)
# $$
# <p>i.e. the log of the product is equal to the sum of logs (so instead of multiplying small numbers we will add them):</p>
# $$
# P(S|x_1,x_2,\dots,x_n)\propto P(S)\cdot P(x_1|S)\cdot \dots \cdot P(x_n|S)$$
# <p>becomes</p>
# $$\log(P(S|x_1,x_2,\dots,x_n))\propto \log\left(P(S)\cdot P(x_1|S)\cdot \dots  P(x_n|S)\right)=$$ $$
# \log(P(S))+\log(P(x_1|S))+\dots+\log(P(x_n|S))
# $$
# <p>So, to check spam or ham we just compare:</p>
# $$
# \log(P(S))+\log(P(x_1|S))+\dots+\log(P(x_n|S))
# $$
# <p>and </p>
# $$
# \log(P(\neg S))+\log(P(x_1|\neg S))+\dots+\log(P(x_n|\neg S))
# $$
#
#
# Change the equation so that logs are used.
# </p>
# <p>[2 Mark]</p>

# %%
# using one of the first 20 messages
message = "i have a date on sunday with will"

# storing log probabilities
log_prob_spam = 0
log_prob_not_spam = 0

words_of_message = message.split()

# loop through message
for word in words_of_message:
    # check if word is in word_prob
    if word in word_prob['Word'].values:
        log_P_E_given_S = np.log(word_prob.loc[word_prob['Word'] == word, 'P(E|S)'].values[0])
        log_P_E_given_not_S = np.log(word_prob.loc[word_prob['Word'] == word, 'P(E|¬S)'].values[0])
        
        # calc log probabilities
        log_prob_spam += log_P_E_given_S
        log_prob_not_spam += log_P_E_given_not_S
        
    else:
        continue

# final calculations for spam and not spam
log_prob_spam += np.log(P_S)
log_prob_not_spam += np.log(P_not_S)

# print results
if log_prob_spam > log_prob_not_spam:
    print("The message is assumed to be spam.")
else:
    print("The message is not assumed to be spam.")
# Out:
# The message is assumed to be spam.

# %% [markdown]
# <h3>10. Testing the Model</h3>
# <p>Now that we have tested the model using simple messages.  Let’s test the model using the messages from the test_set.  You should implement counters that displays how your model has performed and calculate the accuracy of the model.</p>
# <pre>
# match_spam 173
# match_ham 843
# thought_ham_is_spam 3
# thought_spam_is_ham 357
# Accuracy: 0.7383720930232558
# </pre>
# <p>[3 Marks]</p>

# %%
match_spam = 0
match_ham = 0
thought_ham_is_spam = 0
thought_spam_is_ham = 0

for index, row in test_data.iterrows():
    
    message = row['Message']
    category = row['Category']
    
    log_prob_spam = 0
    log_prob_not_spam = 0
    
    words_of_message = message.split()
    
    for word in words_of_message:
        if word in word_prob['Word'].values:
            log_P_E_given_S = np.log(word_prob.loc[word_prob['Word'] == word, 'P(E|S)'].values[0])
            log_P_E_given_not_S = np.log(word_prob.loc[word_prob['Word'] == word, 'P(E|¬S)'].values[0])
            
            log_prob_spam += log_P_E_given_S
            log_prob_not_spam += log_P_E_given_not_S
        else:
            continue
    
    log_prob_spam += np.log(P_S)
    log_prob_not_spam += np.log(P_not_S)
    
    #  classify the message
    if log_prob_spam > log_prob_not_spam:
        if category == 'spam':
            match_spam += 1
        else:
            thought_spam_is_ham += 1
    else:
        if category == 'ham':
            match_ham += 1
        else:
            thought_ham_is_spam += 1
            
# calc accuracy
total_messages = len(test_data)
accuracy = (match_spam + match_ham) / total_messages

# print counters and accuracy
print("match_spam:", match_spam)
print("match_ham:", match_ham)
print("thought_ham_is_spam:", thought_ham_is_spam)
print("thought_spam_is_ham:", thought_spam_is_ham)
print("Accuracy:", accuracy)
# Out:
# match_spam: 107
# match_ham: 612
# thought_ham_is_spam: 5
# thought_spam_is_ham: 112
# Accuracy: 0.8600478468899522

# %% [markdown]
# <h3>11. Improvements</h3>
# <p>Utilise the validation set to assess the performance of various word sets in classifying spam and non-spam (ham) emails. Compare the effectiveness of different sets of words to determine their impact on classification accuracy.</p>
# <p>[3 Mark]</p>

# %%
various_word_sets = [
                ['hello', 'how', 'are', 'you'],
                ['the', 'weather', 'was', 'lovely'],
                ['manchester', 'city', 'is', 'my', 'team'],
                ['how', 'hard', 'will', 'the', 'exam', 'be']
]
                     
accuracies = []

for word_set in various_word_sets:
    
    match_spam = 0
    match_ham = 0
    thought_ham_is_spam = 0
    thought_spam_is_ham = 0
    
    for index, row in validation_data.iterrows():
        
        message = row['Message']
        category = row['Category']
        
        log_prob_spam = 0
        log_prob_not_spam = 0
        
        words_of_message = message.split()
        
        for words in words_of_message:
            if word in various_word_sets:
                log_P_E_given_S = np.log(word_prob.loc[word_prob['Word'] == word, 'P(E|S)'].values[0])
                log_P_E_given_not_S = np.log(word_prob.loc[word_prob['Word'] == word, 'P(E|¬S)'].values[0])
        
                log_prob_spam += log_P_E_given_S
                log_prob_not_spam += log_P_E_given_not_S
                
            else:
                continue
                
        log_prob_spam += np.log(P_S)
        log_prob_not_spam += np.log(P_not_S)
        
        if log_prob_spam > log_prob_not_spam:
            if category == 'spam':
                match_spam += 1
            else:
                thought_spam_is_ham += 1
        else:
            if category == 'ham':
                match_ham += 1
            else:
                thought_ham_is_spam += 1
                
        total_messages = len(validation_data)
        accuracy = (match_spam + match_ham) / total_messages
        accuracies.append(accuracy)
        
for i, accuracy in enumerate(accuracies):
    print("Accuracy for word set", i+1, ":", accuracy)
# Out:
# Accuracy for word set 1 : 0.0011961722488038277
# Accuracy for word set 2 : 0.0023923444976076554
# Accuracy for word set 3 : 0.0035885167464114833
# Accuracy for word set 4 : 0.004784688995215311
# Accuracy for word set 5 : 0.004784688995215311
# Accuracy for word set 6 : 0.005980861244019139
# Accuracy for word set 7 : 0.005980861244019139
# Accuracy for word set 8 : 0.007177033492822967
# Accuracy for word set 9 : 0.008373205741626795
# Accuracy for word set 10 : 0.009569377990430622
# Accuracy for word set 11 : 0.01076555023923445
# Accuracy for word set 12 : 0.011961722488038277
# Accuracy for word set 13 : 0.011961722488038277
# Accuracy for word set 14 : 0.013157894736842105
# Accuracy for word set 15 : 0.013157894736842105
# Accuracy for word set 16 : 0.014354066985645933
# Accuracy for word set 17 : 0.01555023923444976
# Accuracy for word set 18 : 0.01674641148325359
# Accuracy for word set 19 : 0.017942583732057416
# Accuracy for word set 20 : 0.017942583732057416
# Accuracy for word set 21 : 0.019138755980861243
# Accuracy for word set 22 : 0.02033492822966507
# Accuracy for word set 23 : 0.02033492822966507
# Accuracy for word set 24 : 0.0215311004784689
# Accuracy for word set 25 : 0.022727272727272728
# Accuracy for word set 26 : 0.023923444976076555
# Accuracy for word set 27 : 0.025119617224880382
# Accuracy for word set 28 : 0.02631578947368421
# Accuracy for word set 29 : 0.02751196172248804
# Accuracy for word set 30 : 0.028708133971291867
# Accuracy for word set 31 : 0.029904306220095694
# Accuracy for word set 32 : 0.03110047846889952
# Accuracy for word set 33 : 0.03229665071770335
# Accuracy for word set 34 : 0.03349282296650718
# Accuracy for word set 35 : 0.034688995215311005
# Accuracy for word set 36 : 0.03588516746411483
# Accuracy for word set 37 : 0.03708133971291866
# Accuracy for word set 38 : 0.03827751196172249
# Accuracy for word set 39 : 0.039473684210526314
# Accuracy for word set 40 : 0.039473684210526314
# Accuracy for word set 41 : 0.04066985645933014
# Accuracy for word set 42 : 0.041866028708133975
# Accuracy for word set 43 : 0.0430622009569378
# Accuracy for word set 44 : 0.04425837320574163
# Accuracy for word set 45 : 0.04425837320574163
# Accuracy for word set 46 : 0.045454545454545456
# Accuracy for word set 47 : 0.04665071770334928
# Accuracy for word set 48 : 0.04784688995215311
# Accuracy for word set 49 : 0.04904306220095694
# Accuracy for word set 50 : 0.04904306220095694
# Accuracy for word set 51 : 0.04904306220095694
# Accuracy for word set 52 : 0.050239234449760764
# Accuracy for word set 53 : 0.05143540669856459
# Accuracy for word set 54 : 0.05263157894736842
# Accuracy for word set 55 : 0.05382775119617225
# Accuracy for word set 56 : 0.05502392344497608
# Accuracy for word set 57 : 0.056220095693779906
# Accuracy for word set 58 : 0.05741626794258373
# Accuracy for word set 59 : 0.05861244019138756
# Accuracy for word set 60 : 0.05980861244019139
# Accuracy for word set 61 : 0.061004784688995214
# Accuracy for word set 62 : 0.06220095693779904
# Accuracy for word set 63 : 0.06339712918660287
# Accuracy for word set 64 : 0.0645933014354067
# Accuracy for word set 65 : 0.06578947368421052
# Accuracy for word set 66 : 0.06698564593301436
# Accuracy for word set 67 : 0.06818181818181818
# Accuracy for word set 68 : 0.06937799043062201
# Accuracy for word set 69 : 0.07057416267942583
# Accuracy for word set 70 : 0.07057416267942583
# Accuracy for word set 71 : 0.07177033492822966
# Accuracy for word set 72 : 0.0729665071770335
# Accuracy for word set 73 : 0.07416267942583732
# Accuracy for word set 74 : 0.07535885167464115
# Accuracy for word set 75 : 0.07655502392344497
# Accuracy for word set 76 : 0.07775119617224881
# Accuracy for word set 77 : 0.07894736842105263
# Accuracy for word set 78 : 0.08014354066985646
# Accuracy for word set 79 : 0.08133971291866028
# Accuracy for word set 80 : 0.08253588516746412
# Accuracy for word set 81 : 0.08373205741626795
# Accuracy for word set 82 : 0.08492822966507177
# Accuracy for word set 83 : 0.0861244019138756
# Accuracy for word set 84 : 0.08732057416267942
# Accuracy for word set 85 : 0.08851674641148326
# Accuracy for word set 86 : 0.08971291866028708
# Accuracy for word set 87 : 0.09090909090909091
# Accuracy for word set 88 : 0.09210526315789473
# Accuracy for word set 89 : 0.09330143540669857
# Accuracy for word set 90 : 0.09449760765550239
# Accuracy for word set 91 : 0.09569377990430622
# Accuracy for word set 92 : 0.09688995215311005
# Accuracy for word set 93 : 0.09808612440191387
# Accuracy for word set 94 : 0.09808612440191387
# Accuracy for word set 95 : 0.09928229665071771
# Accuracy for word set 96 : 0.10047846889952153
# Accuracy for word set 97 : 0.10167464114832536
# Accuracy for word set 98 : 0.10287081339712918
# Accuracy for word set 99 : 0.10406698564593302
# Accuracy for word set 100 : 0.10526315789473684
# Accuracy for word set 101 : 0.10645933014354067
# Accuracy for word set 102 : 0.1076555023923445
# Accuracy for word set 103 : 0.10885167464114832
# Accuracy for word set 104 : 0.11004784688995216
# Accuracy for word set 105 : 0.11124401913875598
# Accuracy for word set 106 : 0.11244019138755981
# Accuracy for word set 107 : 0.11363636363636363
# Accuracy for word set 108 : 0.11483253588516747
# Accuracy for word set 109 : 0.11602870813397129
# Accuracy for word set 110 : 0.11722488038277512
# Accuracy for word set 111 : 0.11842105263157894
# Accuracy for word set 112 : 0.11961722488038277
# Accuracy for word set 113 : 0.12081339712918661
# Accuracy for word set 114 : 0.12200956937799043
# Accuracy for word set 115 : 0.12320574162679426
# Accuracy for word set 116 : 0.12440191387559808
# Accuracy for word set 117 : 0.12440191387559808
# Accuracy for word set 118 : 0.1255980861244019
# Accuracy for word set 119 : 0.12679425837320574
# Accuracy for word set 120 : 0.12799043062200957
# Accuracy for word set 121 : 0.1291866028708134
# Accuracy for word set 122 : 0.1291866028708134
# Accuracy for word set 123 : 0.1303827751196172
# Accuracy for word set 124 : 0.13157894736842105
# Accuracy for word set 125 : 0.13277511961722488
# Accuracy for word set 126 : 0.1339712918660287
# Accuracy for word set 127 : 0.13516746411483255
# Accuracy for word set 128 : 0.13636363636363635
# Accuracy for word set 129 : 0.1375598086124402
# Accuracy for word set 130 : 0.13875598086124402
# Accuracy for word set 131 : 0.13995215311004786
# Accuracy for word set 132 : 0.14114832535885166
# Accuracy for word set 133 : 0.1423444976076555
# Accuracy for word set 134 : 0.14354066985645933
# Accuracy for word set 135 : 0.14354066985645933
# Accuracy for word set 136 : 0.14473684210526316
# Accuracy for word set 137 : 0.145933014354067
# Accuracy for word set 138 : 0.1471291866028708
# Accuracy for word set 139 : 0.14832535885167464
# Accuracy for word set 140 : 0.14832535885167464
# Accuracy for word set 141 : 0.14952153110047847
# Accuracy for word set 142 : 0.1507177033492823
# Accuracy for word set 143 : 0.1519138755980861
# Accuracy for word set 144 : 0.15311004784688995
# Accuracy for word set 145 : 0.15430622009569378
# Accuracy for word set 146 : 0.15550239234449761
# Accuracy for word set 147 : 0.15669856459330145
# Accuracy for word set 148 : 0.15789473684210525
# Accuracy for word set 149 : 0.1590909090909091
# Accuracy for word set 150 : 0.16028708133971292
# Accuracy for word set 151 : 0.16148325358851676
# Accuracy for word set 152 : 0.16267942583732056
# Accuracy for word set 153 : 0.1638755980861244
# Accuracy for word set 154 : 0.16507177033492823
# Accuracy for word set 155 : 0.16507177033492823
# Accuracy for word set 156 : 0.16626794258373206
# Accuracy for word set 157 : 0.1674641148325359
# Accuracy for word set 158 : 0.1686602870813397
# Accuracy for word set 159 : 0.16985645933014354
# Accuracy for word set 160 : 0.17105263157894737
# Accuracy for word set 161 : 0.1722488038277512
# Accuracy for word set 162 : 0.1722488038277512
# Accuracy for word set 163 : 0.173444976076555
# Accuracy for word set 164 : 0.17464114832535885
# Accuracy for word set 165 : 0.17583732057416268
# Accuracy for word set 166 : 0.17703349282296652
# Accuracy for word set 167 : 0.17822966507177032
# Accuracy for word set 168 : 0.17942583732057416
# Accuracy for word set 169 : 0.180622009569378
# Accuracy for word set 170 : 0.18181818181818182
# Accuracy for word set 171 : 0.18301435406698566
# Accuracy for word set 172 : 0.18421052631578946
# Accuracy for word set 173 : 0.1854066985645933
# Accuracy for word set 174 : 0.18660287081339713
# Accuracy for word set 175 : 0.18660287081339713
# Accuracy for word set 176 : 0.18779904306220097
# Accuracy for word set 177 : 0.18899521531100477
# Accuracy for word set 178 : 0.1901913875598086
# Accuracy for word set 179 : 0.19138755980861244
# Accuracy for word set 180 : 0.19258373205741627
# Accuracy for word set 181 : 0.1937799043062201
# Accuracy for word set 182 : 0.19497607655502391
# Accuracy for word set 183 : 0.19497607655502391
# Accuracy for word set 184 : 0.19497607655502391
# Accuracy for word set 185 : 0.19617224880382775
# Accuracy for word set 186 : 0.19736842105263158
# Accuracy for word set 187 : 0.19856459330143542
# Accuracy for word set 188 : 0.19976076555023922
# Accuracy for word set 189 : 0.20095693779904306
# Accuracy for word set 190 : 0.2021531100478469
# Accuracy for word set 191 : 0.20334928229665072
# Accuracy for word set 192 : 0.20454545454545456
# Accuracy for word set 193 : 0.20574162679425836
# Accuracy for word set 194 : 0.2069377990430622
# Accuracy for word set 195 : 0.20813397129186603
# Accuracy for word set 196 : 0.20933014354066987
# Accuracy for word set 197 : 0.21052631578947367
# Accuracy for word set 198 : 0.2117224880382775
# Accuracy for word set 199 : 0.21291866028708134
# Accuracy for word set 200 : 0.21411483253588517
# Accuracy for word set 201 : 0.21411483253588517
# Accuracy for word set 202 : 0.21411483253588517
# Accuracy for word set 203 : 0.215311004784689
# Accuracy for word set 204 : 0.21650717703349281
# Accuracy for word set 205 : 0.21770334928229665
# Accuracy for word set 206 : 0.21770334928229665
# Accuracy for word set 207 : 0.21889952153110048
# Accuracy for word set 208 : 0.22009569377990432
# Accuracy for word set 209 : 0.22129186602870812
# Accuracy for word set 210 : 0.22248803827751196
# Accuracy for word set 211 : 0.2236842105263158
# Accuracy for word set 212 : 0.22488038277511962
# Accuracy for word set 213 : 0.22607655502392343
# Accuracy for word set 214 : 0.22607655502392343
# Accuracy for word set 215 : 0.22727272727272727
# Accuracy for word set 216 : 0.2284688995215311
# Accuracy for word set 217 : 0.22966507177033493
# Accuracy for word set 218 : 0.23086124401913877
# Accuracy for word set 219 : 0.23086124401913877
# Accuracy for word set 220 : 0.23205741626794257
# Accuracy for word set 221 : 0.2332535885167464
# Accuracy for word set 222 : 0.23444976076555024
# Accuracy for word set 223 : 0.23564593301435408
# Accuracy for word set 224 : 0.23684210526315788
# Accuracy for word set 225 : 0.23803827751196172
# Accuracy for word set 226 : 0.23923444976076555
# Accuracy for word set 227 : 0.24043062200956938
# Accuracy for word set 228 : 0.24162679425837322
# Accuracy for word set 229 : 0.24282296650717702
# Accuracy for word set 230 : 0.24282296650717702
# Accuracy for word set 231 : 0.24401913875598086
# Accuracy for word set 232 : 0.24401913875598086
# Accuracy for word set 233 : 0.2452153110047847
# Accuracy for word set 234 : 0.24641148325358853
# Accuracy for word set 235 : 0.24760765550239233
# Accuracy for word set 236 : 0.24880382775119617
# Accuracy for word set 237 : 0.25
# Accuracy for word set 238 : 0.2511961722488038
# Accuracy for word set 239 : 0.25239234449760767
# Accuracy for word set 240 : 0.2535885167464115
# Accuracy for word set 241 : 0.25478468899521534
# Accuracy for word set 242 : 0.25478468899521534
# Accuracy for word set 243 : 0.25598086124401914
# Accuracy for word set 244 : 0.25717703349282295
# Accuracy for word set 245 : 0.2583732057416268
# Accuracy for word set 246 : 0.2595693779904306
# Accuracy for word set 247 : 0.2607655502392344
# Accuracy for word set 248 : 0.2619617224880383
# Accuracy for word set 249 : 0.2631578947368421
# Accuracy for word set 250 : 0.26435406698564595
# Accuracy for word set 251 : 0.26555023923444976
# Accuracy for word set 252 : 0.26674641148325356
# Accuracy for word set 253 : 0.2679425837320574
# Accuracy for word set 254 : 0.26913875598086123
# Accuracy for word set 255 : 0.26913875598086123
# Accuracy for word set 256 : 0.2703349282296651
# Accuracy for word set 257 : 0.2715311004784689
# Accuracy for word set 258 : 0.2727272727272727
# Accuracy for word set 259 : 0.27392344497607657
# Accuracy for word set 260 : 0.2751196172248804
# Accuracy for word set 261 : 0.27631578947368424
# Accuracy for word set 262 : 0.27751196172248804
# Accuracy for word set 263 : 0.27751196172248804
# Accuracy for word set 264 : 0.27751196172248804
# Accuracy for word set 265 : 0.27870813397129185
# Accuracy for word set 266 : 0.2799043062200957
# Accuracy for word set 267 : 0.2799043062200957
# Accuracy for word set 268 : 0.2811004784688995
# Accuracy for word set 269 : 0.2822966507177033
# Accuracy for word set 270 : 0.2834928229665072
# Accuracy for word set 271 : 0.284688995215311
# Accuracy for word set 272 : 0.284688995215311
# Accuracy for word set 273 : 0.28588516746411485
# Accuracy for word set 274 : 0.28708133971291866
# Accuracy for word set 275 : 0.28827751196172247
# Accuracy for word set 276 : 0.2894736842105263
# Accuracy for word set 277 : 0.29066985645933013
# Accuracy for word set 278 : 0.291866028708134
# Accuracy for word set 279 : 0.2930622009569378
# Accuracy for word set 280 : 0.2930622009569378
# Accuracy for word set 281 : 0.2930622009569378
# Accuracy for word set 282 : 0.2942583732057416
# Accuracy for word set 283 : 0.29545454545454547
# Accuracy for word set 284 : 0.2966507177033493
# Accuracy for word set 285 : 0.29784688995215314
# Accuracy for word set 286 : 0.29904306220095694
# Accuracy for word set 287 : 0.30023923444976075
# Accuracy for word set 288 : 0.30023923444976075
# Accuracy for word set 289 : 0.30023923444976075
# Accuracy for word set 290 : 0.30023923444976075
# Accuracy for word set 291 : 0.3014354066985646
# Accuracy for word set 292 : 0.3026315789473684
# Accuracy for word set 293 : 0.3038277511961722
# Accuracy for word set 294 : 0.3050239234449761
# Accuracy for word set 295 : 0.3062200956937799
# Accuracy for word set 296 : 0.30741626794258375
# Accuracy for word set 297 : 0.30741626794258375
# Accuracy for word set 298 : 0.30861244019138756
# Accuracy for word set 299 : 0.30980861244019137
# Accuracy for word set 300 : 0.31100478468899523
# Accuracy for word set 301 : 0.31100478468899523
# Accuracy for word set 302 : 0.31220095693779903
# Accuracy for word set 303 : 0.3133971291866029
# Accuracy for word set 304 : 0.3145933014354067
# Accuracy for word set 305 : 0.3157894736842105
# Accuracy for word set 306 : 0.31698564593301437
# Accuracy for word set 307 : 0.3181818181818182
# Accuracy for word set 308 : 0.319377990430622
# Accuracy for word set 309 : 0.32057416267942584
# Accuracy for word set 310 : 0.32177033492822965
# Accuracy for word set 311 : 0.3229665071770335
# Accuracy for word set 312 : 0.3241626794258373
# Accuracy for word set 313 : 0.3253588516746411
# Accuracy for word set 314 : 0.3253588516746411
# Accuracy for word set 315 : 0.3253588516746411
# Accuracy for word set 316 : 0.326555023923445
# Accuracy for word set 317 : 0.3277511961722488
# Accuracy for word set 318 : 0.32894736842105265
# Accuracy for word set 319 : 0.32894736842105265
# Accuracy for word set 320 : 0.33014354066985646
# Accuracy for word set 321 : 0.33133971291866027
# Accuracy for word set 322 : 0.33253588516746413
# Accuracy for word set 323 : 0.33373205741626794
# Accuracy for word set 324 : 0.3349282296650718
# Accuracy for word set 325 : 0.3361244019138756
# Accuracy for word set 326 : 0.3373205741626794
# Accuracy for word set 327 : 0.33851674641148327
# Accuracy for word set 328 : 0.3397129186602871
# Accuracy for word set 329 : 0.3409090909090909
# Accuracy for word set 330 : 0.3409090909090909
# Accuracy for word set 331 : 0.34210526315789475
# Accuracy for word set 332 : 0.34210526315789475
# Accuracy for word set 333 : 0.34330143540669855
# Accuracy for word set 334 : 0.3444976076555024
# Accuracy for word set 335 : 0.3444976076555024
# Accuracy for word set 336 : 0.3456937799043062
# Accuracy for word set 337 : 0.34688995215311
# Accuracy for word set 338 : 0.3480861244019139
# Accuracy for word set 339 : 0.3480861244019139
# Accuracy for word set 340 : 0.3492822966507177
# Accuracy for word set 341 : 0.35047846889952156
# Accuracy for word set 342 : 0.35167464114832536
# Accuracy for word set 343 : 0.35167464114832536
# Accuracy for word set 344 : 0.35287081339712917
# Accuracy for word set 345 : 0.35406698564593303
# Accuracy for word set 346 : 0.35406698564593303
# Accuracy for word set 347 : 0.35526315789473684
# Accuracy for word set 348 : 0.35645933014354064
# Accuracy for word set 349 : 0.3576555023923445
# Accuracy for word set 350 : 0.3588516746411483
# Accuracy for word set 351 : 0.36004784688995217
# Accuracy for word set 352 : 0.361244019138756
# Accuracy for word set 353 : 0.361244019138756
# Accuracy for word set 354 : 0.3624401913875598
# Accuracy for word set 355 : 0.36363636363636365
# Accuracy for word set 356 : 0.36483253588516745
# Accuracy for word set 357 : 0.3660287081339713
# Accuracy for word set 358 : 0.3672248803827751
# Accuracy for word set 359 : 0.3684210526315789
# Accuracy for word set 360 : 0.3696172248803828
# Accuracy for word set 361 : 0.3708133971291866
# Accuracy for word set 362 : 0.37200956937799046
# Accuracy for word set 363 : 0.37320574162679426
# Accuracy for word set 364 : 0.37440191387559807
# Accuracy for word set 365 : 0.37440191387559807
# Accuracy for word set 366 : 0.37559808612440193
# Accuracy for word set 367 : 0.37679425837320574
# Accuracy for word set 368 : 0.37799043062200954
# Accuracy for word set 369 : 0.3791866028708134
# Accuracy for word set 370 : 0.3803827751196172
# Accuracy for word set 371 : 0.3815789473684211
# Accuracy for word set 372 : 0.3827751196172249
# Accuracy for word set 373 : 0.3839712918660287
# Accuracy for word set 374 : 0.38516746411483255
# Accuracy for word set 375 : 0.38636363636363635
# Accuracy for word set 376 : 0.3875598086124402
# Accuracy for word set 377 : 0.388755980861244
# Accuracy for word set 378 : 0.388755980861244
# Accuracy for word set 379 : 0.388755980861244
# Accuracy for word set 380 : 0.38995215311004783
# Accuracy for word set 381 : 0.3911483253588517
# Accuracy for word set 382 : 0.3923444976076555
# Accuracy for word set 383 : 0.39354066985645936
# Accuracy for word set 384 : 0.39473684210526316
# Accuracy for word set 385 : 0.39473684210526316
# Accuracy for word set 386 : 0.39473684210526316
# Accuracy for word set 387 : 0.39473684210526316
# Accuracy for word set 388 : 0.39593301435406697
# Accuracy for word set 389 : 0.39712918660287083
# Accuracy for word set 390 : 0.39832535885167464
# Accuracy for word set 391 : 0.39952153110047844
# Accuracy for word set 392 : 0.4007177033492823
# Accuracy for word set 393 : 0.4019138755980861
# Accuracy for word set 394 : 0.40311004784689
# Accuracy for word set 395 : 0.4043062200956938
# Accuracy for word set 396 : 0.4055023923444976
# Accuracy for word set 397 : 0.40669856459330145
# Accuracy for word set 398 : 0.40789473684210525
# Accuracy for word set 399 : 0.4090909090909091
# Accuracy for word set 400 : 0.4102870813397129
# Accuracy for word set 401 : 0.41148325358851673
# Accuracy for word set 402 : 0.4126794258373206
# Accuracy for word set 403 : 0.4138755980861244
# Accuracy for word set 404 : 0.4138755980861244
# Accuracy for word set 405 : 0.4150717703349282
# Accuracy for word set 406 : 0.41626794258373206
# Accuracy for word set 407 : 0.41746411483253587
# Accuracy for word set 408 : 0.41866028708133973
# Accuracy for word set 409 : 0.41985645933014354
# Accuracy for word set 410 : 0.41985645933014354
# Accuracy for word set 411 : 0.42105263157894735
# Accuracy for word set 412 : 0.4222488038277512
# Accuracy for word set 413 : 0.423444976076555
# Accuracy for word set 414 : 0.4246411483253589
# Accuracy for word set 415 : 0.4246411483253589
# Accuracy for word set 416 : 0.4258373205741627
# Accuracy for word set 417 : 0.4270334928229665
# Accuracy for word set 418 : 0.4270334928229665
# Accuracy for word set 419 : 0.42822966507177035
# Accuracy for word set 420 : 0.42942583732057416
# Accuracy for word set 421 : 0.430622009569378
# Accuracy for word set 422 : 0.430622009569378
# Accuracy for word set 423 : 0.4318181818181818
# Accuracy for word set 424 : 0.43301435406698563
# Accuracy for word set 425 : 0.4342105263157895
# Accuracy for word set 426 : 0.4342105263157895
# Accuracy for word set 427 : 0.4354066985645933
# Accuracy for word set 428 : 0.4366028708133971
# Accuracy for word set 429 : 0.43779904306220097
# Accuracy for word set 430 : 0.43899521531100477
# Accuracy for word set 431 : 0.44019138755980863
# Accuracy for word set 432 : 0.44138755980861244
# Accuracy for word set 433 : 0.44138755980861244
# Accuracy for word set 434 : 0.44138755980861244
# Accuracy for word set 435 : 0.44258373205741625
# Accuracy for word set 436 : 0.4437799043062201
# Accuracy for word set 437 : 0.4449760765550239
# Accuracy for word set 438 : 0.4449760765550239
# Accuracy for word set 439 : 0.4461722488038278
# Accuracy for word set 440 : 0.4473684210526316
# Accuracy for word set 441 : 0.4485645933014354
# Accuracy for word set 442 : 0.44976076555023925
# Accuracy for word set 443 : 0.45095693779904306
# Accuracy for word set 444 : 0.45215311004784686
# Accuracy for word set 445 : 0.4533492822966507
# Accuracy for word set 446 : 0.45454545454545453
# Accuracy for word set 447 : 0.4557416267942584
# Accuracy for word set 448 : 0.4569377990430622
# Accuracy for word set 449 : 0.458133971291866
# Accuracy for word set 450 : 0.45933014354066987
# Accuracy for word set 451 : 0.4605263157894737
# Accuracy for word set 452 : 0.46172248803827753
# Accuracy for word set 453 : 0.46291866028708134
# Accuracy for word set 454 : 0.46411483253588515
# Accuracy for word set 455 : 0.465311004784689
# Accuracy for word set 456 : 0.4665071770334928
# Accuracy for word set 457 : 0.4677033492822967
# Accuracy for word set 458 : 0.4688995215311005
# Accuracy for word set 459 : 0.4700956937799043
# Accuracy for word set 460 : 0.47129186602870815
# Accuracy for word set 461 : 0.47248803827751196
# Accuracy for word set 462 : 0.47368421052631576
# Accuracy for word set 463 : 0.4748803827751196
# Accuracy for word set 464 : 0.47607655502392343
# Accuracy for word set 465 : 0.4772727272727273
# Accuracy for word set 466 : 0.4784688995215311
# Accuracy for word set 467 : 0.4796650717703349
# Accuracy for word set 468 : 0.4796650717703349
# Accuracy for word set 469 : 0.48086124401913877
# Accuracy for word set 470 : 0.4820574162679426
# Accuracy for word set 471 : 0.48325358851674644
# Accuracy for word set 472 : 0.48325358851674644
# Accuracy for word set 473 : 0.48444976076555024
# Accuracy for word set 474 : 0.48564593301435405
# Accuracy for word set 475 : 0.48564593301435405
# Accuracy for word set 476 : 0.4868421052631579
# Accuracy for word set 477 : 0.4880382775119617
# Accuracy for word set 478 : 0.4892344497607656
# Accuracy for word set 479 : 0.4892344497607656
# Accuracy for word set 480 : 0.4892344497607656
# Accuracy for word set 481 : 0.4904306220095694
# Accuracy for word set 482 : 0.4916267942583732
# Accuracy for word set 483 : 0.49282296650717705
# Accuracy for word set 484 : 0.49401913875598086
# Accuracy for word set 485 : 0.49521531100478466
# Accuracy for word set 486 : 0.4964114832535885
# Accuracy for word set 487 : 0.49760765550239233
# Accuracy for word set 488 : 0.4988038277511962
# Accuracy for word set 489 : 0.5
# Accuracy for word set 490 : 0.5011961722488039
# Accuracy for word set 491 : 0.5023923444976076
# Accuracy for word set 492 : 0.5023923444976076
# Accuracy for word set 493 : 0.5035885167464115
# Accuracy for word set 494 : 0.5035885167464115
# Accuracy for word set 495 : 0.5035885167464115
# Accuracy for word set 496 : 0.5047846889952153
# Accuracy for word set 497 : 0.5047846889952153
# Accuracy for word set 498 : 0.5059808612440191
# Accuracy for word set 499 : 0.507177033492823
# Accuracy for word set 500 : 0.5083732057416268
# Accuracy for word set 501 : 0.5095693779904307
# Accuracy for word set 502 : 0.5107655502392344
# Accuracy for word set 503 : 0.5119617224880383
# Accuracy for word set 504 : 0.5131578947368421
# Accuracy for word set 505 : 0.5143540669856459
# Accuracy for word set 506 : 0.5143540669856459
# Accuracy for word set 507 : 0.5155502392344498
# Accuracy for word set 508 : 0.5155502392344498
# Accuracy for word set 509 : 0.5167464114832536
# Accuracy for word set 510 : 0.5179425837320574
# Accuracy for word set 511 : 0.5191387559808612
# Accuracy for word set 512 : 0.5203349282296651
# Accuracy for word set 513 : 0.5215311004784688
# Accuracy for word set 514 : 0.5227272727272727
# Accuracy for word set 515 : 0.5239234449760766
# Accuracy for word set 516 : 0.5251196172248804
# Accuracy for word set 517 : 0.5263157894736842
# Accuracy for word set 518 : 0.527511961722488
# Accuracy for word set 519 : 0.5287081339712919
# Accuracy for word set 520 : 0.5299043062200957
# Accuracy for word set 521 : 0.5311004784688995
# Accuracy for word set 522 : 0.5311004784688995
# Accuracy for word set 523 : 0.5322966507177034
# Accuracy for word set 524 : 0.5334928229665071
# Accuracy for word set 525 : 0.534688995215311
# Accuracy for word set 526 : 0.5358851674641149
# Accuracy for word set 527 : 0.5370813397129187
# Accuracy for word set 528 : 0.5382775119617225
# Accuracy for word set 529 : 0.5394736842105263
# Accuracy for word set 530 : 0.5394736842105263
# Accuracy for word set 531 : 0.5406698564593302
# Accuracy for word set 532 : 0.5418660287081339
# Accuracy for word set 533 : 0.5430622009569378
# Accuracy for word set 534 : 0.5442583732057417
# Accuracy for word set 535 : 0.5454545454545454
# Accuracy for word set 536 : 0.5454545454545454
# Accuracy for word set 537 : 0.5466507177033493
# Accuracy for word set 538 : 0.5478468899521531
# Accuracy for word set 539 : 0.5490430622009569
# Accuracy for word set 540 : 0.5502392344497608
# Accuracy for word set 541 : 0.5514354066985646
# Accuracy for word set 542 : 0.5526315789473685
# Accuracy for word set 543 : 0.5538277511961722
# Accuracy for word set 544 : 0.5550239234449761
# Accuracy for word set 545 : 0.55622009569378
# Accuracy for word set 546 : 0.5574162679425837
# Accuracy for word set 547 : 0.5586124401913876
# Accuracy for word set 548 : 0.5598086124401914
# Accuracy for word set 549 : 0.5610047846889952
# Accuracy for word set 550 : 0.562200956937799
# Accuracy for word set 551 : 0.5633971291866029
# Accuracy for word set 552 : 0.5645933014354066
# Accuracy for word set 553 : 0.5657894736842105
# Accuracy for word set 554 : 0.5669856459330144
# Accuracy for word set 555 : 0.5681818181818182
# Accuracy for word set 556 : 0.569377990430622
# Accuracy for word set 557 : 0.5705741626794258
# Accuracy for word set 558 : 0.5717703349282297
# Accuracy for word set 559 : 0.5717703349282297
# Accuracy for word set 560 : 0.5729665071770335
# Accuracy for word set 561 : 0.5741626794258373
# Accuracy for word set 562 : 0.5753588516746412
# Accuracy for word set 563 : 0.5765550239234449
# Accuracy for word set 564 : 0.5777511961722488
# Accuracy for word set 565 : 0.5789473684210527
# Accuracy for word set 566 : 0.5801435406698564
# Accuracy for word set 567 : 0.5813397129186603
# Accuracy for word set 568 : 0.5825358851674641
# Accuracy for word set 569 : 0.583732057416268
# Accuracy for word set 570 : 0.5849282296650717
# Accuracy for word set 571 : 0.5849282296650717
# Accuracy for word set 572 : 0.5861244019138756
# Accuracy for word set 573 : 0.5873205741626795
# Accuracy for word set 574 : 0.5885167464114832
# Accuracy for word set 575 : 0.5897129186602871
# Accuracy for word set 576 : 0.5909090909090909
# Accuracy for word set 577 : 0.5921052631578947
# Accuracy for word set 578 : 0.5933014354066986
# Accuracy for word set 579 : 0.5944976076555024
# Accuracy for word set 580 : 0.5944976076555024
# Accuracy for word set 581 : 0.5956937799043063
# Accuracy for word set 582 : 0.59688995215311
# Accuracy for word set 583 : 0.5980861244019139
# Accuracy for word set 584 : 0.5992822966507177
# Accuracy for word set 585 : 0.6004784688995215
# Accuracy for word set 586 : 0.6004784688995215
# Accuracy for word set 587 : 0.6016746411483254
# Accuracy for word set 588 : 0.6028708133971292
# Accuracy for word set 589 : 0.604066985645933
# Accuracy for word set 590 : 0.6052631578947368
# Accuracy for word set 591 : 0.6064593301435407
# Accuracy for word set 592 : 0.6064593301435407
# Accuracy for word set 593 : 0.6076555023923444
# Accuracy for word set 594 : 0.6088516746411483
# Accuracy for word set 595 : 0.6088516746411483
# Accuracy for word set 596 : 0.6100478468899522
# Accuracy for word set 597 : 0.611244019138756
# Accuracy for word set 598 : 0.6124401913875598
# Accuracy for word set 599 : 0.6136363636363636
# Accuracy for word set 600 : 0.6148325358851675
# Accuracy for word set 601 : 0.6160287081339713
# Accuracy for word set 602 : 0.6172248803827751
# Accuracy for word set 603 : 0.618421052631579
# Accuracy for word set 604 : 0.6196172248803827
# Accuracy for word set 605 : 0.6208133971291866
# Accuracy for word set 606 : 0.6220095693779905
# Accuracy for word set 607 : 0.6220095693779905
# Accuracy for word set 608 : 0.6232057416267942
# Accuracy for word set 609 : 0.6232057416267942
# Accuracy for word set 610 : 0.6232057416267942
# Accuracy for word set 611 : 0.6244019138755981
# Accuracy for word set 612 : 0.6255980861244019
# Accuracy for word set 613 : 0.6267942583732058
# Accuracy for word set 614 : 0.6279904306220095
# Accuracy for word set 615 : 0.6291866028708134
# Accuracy for word set 616 : 0.6303827751196173
# Accuracy for word set 617 : 0.631578947368421
# Accuracy for word set 618 : 0.6327751196172249
# Accuracy for word set 619 : 0.6339712918660287
# Accuracy for word set 620 : 0.6351674641148325
# Accuracy for word set 621 : 0.6363636363636364
# Accuracy for word set 622 : 0.6375598086124402
# Accuracy for word set 623 : 0.638755980861244
# Accuracy for word set 624 : 0.638755980861244
# Accuracy for word set 625 : 0.6399521531100478
# Accuracy for word set 626 : 0.6411483253588517
# Accuracy for word set 627 : 0.6423444976076556
# Accuracy for word set 628 : 0.6435406698564593
# Accuracy for word set 629 : 0.6447368421052632
# Accuracy for word set 630 : 0.6447368421052632
# Accuracy for word set 631 : 0.645933014354067
# Accuracy for word set 632 : 0.6471291866028708
# Accuracy for word set 633 : 0.6483253588516746
# Accuracy for word set 634 : 0.6495215311004785
# Accuracy for word set 635 : 0.6507177033492823
# Accuracy for word set 636 : 0.6519138755980861
# Accuracy for word set 637 : 0.65311004784689
# Accuracy for word set 638 : 0.6543062200956937
# Accuracy for word set 639 : 0.6555023923444976
# Accuracy for word set 640 : 0.6566985645933014
# Accuracy for word set 641 : 0.6578947368421053
# Accuracy for word set 642 : 0.6590909090909091
# Accuracy for word set 643 : 0.6602870813397129
# Accuracy for word set 644 : 0.6614832535885168
# Accuracy for word set 645 : 0.6626794258373205
# Accuracy for word set 646 : 0.6638755980861244
# Accuracy for word set 647 : 0.6650717703349283
# Accuracy for word set 648 : 0.666267942583732
# Accuracy for word set 649 : 0.6674641148325359
# Accuracy for word set 650 : 0.6686602870813397
# Accuracy for word set 651 : 0.6698564593301436
# Accuracy for word set 652 : 0.6710526315789473
# Accuracy for word set 653 : 0.6722488038277512
# Accuracy for word set 654 : 0.6734449760765551
# Accuracy for word set 655 : 0.6734449760765551
# Accuracy for word set 656 : 0.6746411483253588
# Accuracy for word set 657 : 0.6758373205741627
# Accuracy for word set 658 : 0.6770334928229665
# Accuracy for word set 659 : 0.6782296650717703
# Accuracy for word set 660 : 0.6794258373205742
# Accuracy for word set 661 : 0.680622009569378
# Accuracy for word set 662 : 0.6818181818181818
# Accuracy for word set 663 : 0.6830143540669856
# Accuracy for word set 664 : 0.6842105263157895
# Accuracy for word set 665 : 0.6854066985645934
# Accuracy for word set 666 : 0.6866028708133971
# Accuracy for word set 667 : 0.687799043062201
# Accuracy for word set 668 : 0.6889952153110048
# Accuracy for word set 669 : 0.6901913875598086
# Accuracy for word set 670 : 0.6913875598086124
# Accuracy for word set 671 : 0.6925837320574163
# Accuracy for word set 672 : 0.69377990430622
# Accuracy for word set 673 : 0.6949760765550239
# Accuracy for word set 674 : 0.6961722488038278
# Accuracy for word set 675 : 0.6973684210526315
# Accuracy for word set 676 : 0.6985645933014354
# Accuracy for word set 677 : 0.6985645933014354
# Accuracy for word set 678 : 0.6997607655502392
# Accuracy for word set 679 : 0.7009569377990431
# Accuracy for word set 680 : 0.7021531100478469
# Accuracy for word set 681 : 0.7033492822966507
# Accuracy for word set 682 : 0.7045454545454546
# Accuracy for word set 683 : 0.7045454545454546
# Accuracy for word set 684 : 0.7057416267942583
# Accuracy for word set 685 : 0.7069377990430622
# Accuracy for word set 686 : 0.7081339712918661
# Accuracy for word set 687 : 0.7093301435406698
# Accuracy for word set 688 : 0.7105263157894737
# Accuracy for word set 689 : 0.7117224880382775
# Accuracy for word set 690 : 0.7129186602870813
# Accuracy for word set 691 : 0.7141148325358851
# Accuracy for word set 692 : 0.715311004784689
# Accuracy for word set 693 : 0.7165071770334929
# Accuracy for word set 694 : 0.7177033492822966
# Accuracy for word set 695 : 0.7188995215311005
# Accuracy for word set 696 : 0.7200956937799043
# Accuracy for word set 697 : 0.7212918660287081
# Accuracy for word set 698 : 0.722488038277512
# Accuracy for word set 699 : 0.7236842105263158
# Accuracy for word set 700 : 0.7248803827751196
# Accuracy for word set 701 : 0.7260765550239234
# Accuracy for word set 702 : 0.7272727272727273
# Accuracy for word set 703 : 0.7284688995215312
# Accuracy for word set 704 : 0.7284688995215312
# Accuracy for word set 705 : 0.7296650717703349
# Accuracy for word set 706 : 0.7308612440191388
# Accuracy for word set 707 : 0.7320574162679426
# Accuracy for word set 708 : 0.7332535885167464
# Accuracy for word set 709 : 0.7344497607655502
# Accuracy for word set 710 : 0.7356459330143541
# Accuracy for word set 711 : 0.7368421052631579
# Accuracy for word set 712 : 0.7380382775119617
# Accuracy for word set 713 : 0.7392344497607656
# Accuracy for word set 714 : 0.7404306220095693
# Accuracy for word set 715 : 0.7416267942583732
# Accuracy for word set 716 : 0.742822966507177
# Accuracy for word set 717 : 0.7440191387559809
# Accuracy for word set 718 : 0.7452153110047847
# Accuracy for word set 719 : 0.7464114832535885
# Accuracy for word set 720 : 0.7476076555023924
# Accuracy for word set 721 : 0.7488038277511961
# Accuracy for word set 722 : 0.75
# Accuracy for word set 723 : 0.7511961722488039
# Accuracy for word set 724 : 0.7523923444976076
# Accuracy for word set 725 : 0.7535885167464115
# Accuracy for word set 726 : 0.7535885167464115
# Accuracy for word set 727 : 0.7547846889952153
# Accuracy for word set 728 : 0.7559808612440191
# Accuracy for word set 729 : 0.757177033492823
# Accuracy for word set 730 : 0.7583732057416268
# Accuracy for word set 731 : 0.7595693779904307
# Accuracy for word set 732 : 0.7607655502392344
# Accuracy for word set 733 : 0.7607655502392344
# Accuracy for word set 734 : 0.7619617224880383
# Accuracy for word set 735 : 0.7631578947368421
# Accuracy for word set 736 : 0.7631578947368421
# Accuracy for word set 737 : 0.7643540669856459
# Accuracy for word set 738 : 0.7655502392344498
# Accuracy for word set 739 : 0.7667464114832536
# Accuracy for word set 740 : 0.7679425837320574
# Accuracy for word set 741 : 0.7691387559808612
# Accuracy for word set 742 : 0.7691387559808612
# Accuracy for word set 743 : 0.7703349282296651
# Accuracy for word set 744 : 0.7715311004784688
# Accuracy for word set 745 : 0.7727272727272727
# Accuracy for word set 746 : 0.7739234449760766
# Accuracy for word set 747 : 0.7751196172248804
# Accuracy for word set 748 : 0.7763157894736842
# Accuracy for word set 749 : 0.777511961722488
# Accuracy for word set 750 : 0.7787081339712919
# Accuracy for word set 751 : 0.7799043062200957
# Accuracy for word set 752 : 0.7811004784688995
# Accuracy for word set 753 : 0.7822966507177034
# Accuracy for word set 754 : 0.7834928229665071
# Accuracy for word set 755 : 0.784688995215311
# Accuracy for word set 756 : 0.7858851674641149
# Accuracy for word set 757 : 0.7870813397129187
# Accuracy for word set 758 : 0.7882775119617225
# Accuracy for word set 759 : 0.7894736842105263
# Accuracy for word set 760 : 0.7906698564593302
# Accuracy for word set 761 : 0.7918660287081339
# Accuracy for word set 762 : 0.7930622009569378
# Accuracy for word set 763 : 0.7942583732057417
# Accuracy for word set 764 : 0.7954545454545454
# Accuracy for word set 765 : 0.7966507177033493
# Accuracy for word set 766 : 0.7978468899521531
# Accuracy for word set 767 : 0.7990430622009569
# Accuracy for word set 768 : 0.8002392344497608
# Accuracy for word set 769 : 0.8002392344497608
# Accuracy for word set 770 : 0.8014354066985646
# Accuracy for word set 771 : 0.8014354066985646
# Accuracy for word set 772 : 0.8026315789473685
# Accuracy for word set 773 : 0.8038277511961722
# Accuracy for word set 774 : 0.8050239234449761
# Accuracy for word set 775 : 0.80622009569378
# Accuracy for word set 776 : 0.8074162679425837
# Accuracy for word set 777 : 0.8086124401913876
# Accuracy for word set 778 : 0.8098086124401914
# Accuracy for word set 779 : 0.8110047846889952
# Accuracy for word set 780 : 0.812200956937799
# Accuracy for word set 781 : 0.8133971291866029
# Accuracy for word set 782 : 0.8145933014354066
# Accuracy for word set 783 : 0.8157894736842105
# Accuracy for word set 784 : 0.8169856459330144
# Accuracy for word set 785 : 0.8181818181818182
# Accuracy for word set 786 : 0.819377990430622
# Accuracy for word set 787 : 0.8205741626794258
# Accuracy for word set 788 : 0.8217703349282297
# Accuracy for word set 789 : 0.8229665071770335
# Accuracy for word set 790 : 0.8241626794258373
# Accuracy for word set 791 : 0.8253588516746412
# Accuracy for word set 792 : 0.8265550239234449
# Accuracy for word set 793 : 0.8277511961722488
# Accuracy for word set 794 : 0.8289473684210527
# Accuracy for word set 795 : 0.8301435406698564
# Accuracy for word set 796 : 0.8313397129186603
# Accuracy for word set 797 : 0.8325358851674641
# Accuracy for word set 798 : 0.833732057416268
# Accuracy for word set 799 : 0.8349282296650717
# Accuracy for word set 800 : 0.8361244019138756
# Accuracy for word set 801 : 0.8373205741626795
# Accuracy for word set 802 : 0.8385167464114832
# Accuracy for word set 803 : 0.8397129186602871
# Accuracy for word set 804 : 0.8409090909090909
# Accuracy for word set 805 : 0.8421052631578947
# Accuracy for word set 806 : 0.8421052631578947
# Accuracy for word set 807 : 0.8433014354066986
# Accuracy for word set 808 : 0.8444976076555024
# Accuracy for word set 809 : 0.8456937799043063
# Accuracy for word set 810 : 0.84688995215311
# Accuracy for word set 811 : 0.8480861244019139
# Accuracy for word set 812 : 0.8492822966507177
# Accuracy for word set 813 : 0.8504784688995215
# Accuracy for word set 814 : 0.8516746411483254
# Accuracy for word set 815 : 0.8528708133971292
# Accuracy for word set 816 : 0.854066985645933
# Accuracy for word set 817 : 0.854066985645933
# Accuracy for word set 818 : 0.854066985645933
# Accuracy for word set 819 : 0.8552631578947368
# Accuracy for word set 820 : 0.8564593301435407
# Accuracy for word set 821 : 0.8576555023923444
# Accuracy for word set 822 : 0.8588516746411483
# Accuracy for word set 823 : 0.8600478468899522
# Accuracy for word set 824 : 0.861244019138756
# Accuracy for word set 825 : 0.8624401913875598
# Accuracy for word set 826 : 0.8636363636363636
# Accuracy for word set 827 : 0.8648325358851675
# Accuracy for word set 828 : 0.8660287081339713
# Accuracy for word set 829 : 0.8672248803827751
# Accuracy for word set 830 : 0.8672248803827751
# Accuracy for word set 831 : 0.868421052631579
# Accuracy for word set 832 : 0.8696172248803827
# Accuracy for word set 833 : 0.8708133971291866
# Accuracy for word set 834 : 0.8708133971291866
# Accuracy for word set 835 : 0.8708133971291866
# Accuracy for word set 836 : 0.8720095693779905
# Accuracy for word set 837 : 0.0011961722488038277
# Accuracy for word set 838 : 0.0023923444976076554
# Accuracy for word set 839 : 0.0035885167464114833
# Accuracy for word set 840 : 0.004784688995215311
# Accuracy for word set 841 : 0.004784688995215311
# Accuracy for word set 842 : 0.005980861244019139
# Accuracy for word set 843 : 0.005980861244019139
# Accuracy for word set 844 : 0.007177033492822967
# Accuracy for word set 845 : 0.008373205741626795
# Accuracy for word set 846 : 0.009569377990430622
# Accuracy for word set 847 : 0.01076555023923445
# Accuracy for word set 848 : 0.011961722488038277
# Accuracy for word set 849 : 0.011961722488038277
# Accuracy for word set 850 : 0.013157894736842105
# Accuracy for word set 851 : 0.013157894736842105
# Accuracy for word set 852 : 0.014354066985645933
# Accuracy for word set 853 : 0.01555023923444976
# Accuracy for word set 854 : 0.01674641148325359
# Accuracy for word set 855 : 0.017942583732057416
# Accuracy for word set 856 : 0.017942583732057416
# Accuracy for word set 857 : 0.019138755980861243
# Accuracy for word set 858 : 0.02033492822966507
# Accuracy for word set 859 : 0.02033492822966507
# Accuracy for word set 860 : 0.0215311004784689
# Accuracy for word set 861 : 0.022727272727272728
# Accuracy for word set 862 : 0.023923444976076555
# Accuracy for word set 863 : 0.025119617224880382
# Accuracy for word set 864 : 0.02631578947368421
# Accuracy for word set 865 : 0.02751196172248804
# Accuracy for word set 866 : 0.028708133971291867
# Accuracy for word set 867 : 0.029904306220095694
# Accuracy for word set 868 : 0.03110047846889952
# Accuracy for word set 869 : 0.03229665071770335
# Accuracy for word set 870 : 0.03349282296650718
# Accuracy for word set 871 : 0.034688995215311005
# Accuracy for word set 872 : 0.03588516746411483
# Accuracy for word set 873 : 0.03708133971291866
# Accuracy for word set 874 : 0.03827751196172249
# Accuracy for word set 875 : 0.039473684210526314
# Accuracy for word set 876 : 0.039473684210526314
# Accuracy for word set 877 : 0.04066985645933014
# Accuracy for word set 878 : 0.041866028708133975
# Accuracy for word set 879 : 0.0430622009569378
# Accuracy for word set 880 : 0.04425837320574163
# Accuracy for word set 881 : 0.04425837320574163
# Accuracy for word set 882 : 0.045454545454545456
# Accuracy for word set 883 : 0.04665071770334928
# Accuracy for word set 884 : 0.04784688995215311
# Accuracy for word set 885 : 0.04904306220095694
# Accuracy for word set 886 : 0.04904306220095694
# Accuracy for word set 887 : 0.04904306220095694
# Accuracy for word set 888 : 0.050239234449760764
# Accuracy for word set 889 : 0.05143540669856459
# Accuracy for word set 890 : 0.05263157894736842
# Accuracy for word set 891 : 0.05382775119617225
# Accuracy for word set 892 : 0.05502392344497608
# Accuracy for word set 893 : 0.056220095693779906
# Accuracy for word set 894 : 0.05741626794258373
# Accuracy for word set 895 : 0.05861244019138756
# Accuracy for word set 896 : 0.05980861244019139
# Accuracy for word set 897 : 0.061004784688995214
# Accuracy for word set 898 : 0.06220095693779904
# Accuracy for word set 899 : 0.06339712918660287
# Accuracy for word set 900 : 0.0645933014354067
# Accuracy for word set 901 : 0.06578947368421052
# Accuracy for word set 902 : 0.06698564593301436
# Accuracy for word set 903 : 0.06818181818181818
# Accuracy for word set 904 : 0.06937799043062201
# Accuracy for word set 905 : 0.07057416267942583
# Accuracy for word set 906 : 0.07057416267942583
# Accuracy for word set 907 : 0.07177033492822966
# Accuracy for word set 908 : 0.0729665071770335
# Accuracy for word set 909 : 0.07416267942583732
# Accuracy for word set 910 : 0.07535885167464115
# Accuracy for word set 911 : 0.07655502392344497
# Accuracy for word set 912 : 0.07775119617224881
# Accuracy for word set 913 : 0.07894736842105263
# Accuracy for word set 914 : 0.08014354066985646
# Accuracy for word set 915 : 0.08133971291866028
# Accuracy for word set 916 : 0.08253588516746412
# Accuracy for word set 917 : 0.08373205741626795
# Accuracy for word set 918 : 0.08492822966507177
# Accuracy for word set 919 : 0.0861244019138756
# Accuracy for word set 920 : 0.08732057416267942
# Accuracy for word set 921 : 0.08851674641148326
# Accuracy for word set 922 : 0.08971291866028708
# Accuracy for word set 923 : 0.09090909090909091
# Accuracy for word set 924 : 0.09210526315789473
# Accuracy for word set 925 : 0.09330143540669857
# Accuracy for word set 926 : 0.09449760765550239
# Accuracy for word set 927 : 0.09569377990430622
# Accuracy for word set 928 : 0.09688995215311005
# Accuracy for word set 929 : 0.09808612440191387
# Accuracy for word set 930 : 0.09808612440191387
# Accuracy for word set 931 : 0.09928229665071771
# Accuracy for word set 932 : 0.10047846889952153
# Accuracy for word set 933 : 0.10167464114832536
# Accuracy for word set 934 : 0.10287081339712918
# Accuracy for word set 935 : 0.10406698564593302
# Accuracy for word set 936 : 0.10526315789473684
# Accuracy for word set 937 : 0.10645933014354067
# Accuracy for word set 938 : 0.1076555023923445
# Accuracy for word set 939 : 0.10885167464114832
# Accuracy for word set 940 : 0.11004784688995216
# Accuracy for word set 941 : 0.11124401913875598
# Accuracy for word set 942 : 0.11244019138755981
# Accuracy for word set 943 : 0.11363636363636363
# Accuracy for word set 944 : 0.11483253588516747
# Accuracy for word set 945 : 0.11602870813397129
# Accuracy for word set 946 : 0.11722488038277512
# Accuracy for word set 947 : 0.11842105263157894
# Accuracy for word set 948 : 0.11961722488038277
# Accuracy for word set 949 : 0.12081339712918661
# Accuracy for word set 950 : 0.12200956937799043
# Accuracy for word set 951 : 0.12320574162679426
# Accuracy for word set 952 : 0.12440191387559808
# Accuracy for word set 953 : 0.12440191387559808
# Accuracy for word set 954 : 0.1255980861244019
# Accuracy for word set 955 : 0.12679425837320574
# Accuracy for word set 956 : 0.12799043062200957
# Accuracy for word set 957 : 0.1291866028708134
# Accuracy for word set 958 : 0.1291866028708134
# Accuracy for word set 959 : 0.1303827751196172
# Accuracy for word set 960 : 0.13157894736842105
# Accuracy for word set 961 : 0.13277511961722488
# Accuracy for word set 962 : 0.1339712918660287
# Accuracy for word set 963 : 0.13516746411483255
# Accuracy for word set 964 : 0.13636363636363635
# Accuracy for word set 965 : 0.1375598086124402
# Accuracy for word set 966 : 0.13875598086124402
# Accuracy for word set 967 : 0.13995215311004786
# Accuracy for word set 968 : 0.14114832535885166
# Accuracy for word set 969 : 0.1423444976076555
# Accuracy for word set 970 : 0.14354066985645933
# Accuracy for word set 971 : 0.14354066985645933
# Accuracy for word set 972 : 0.14473684210526316
# Accuracy for word set 973 : 0.145933014354067
# Accuracy for word set 974 : 0.1471291866028708
# Accuracy for word set 975 : 0.14832535885167464
# Accuracy for word set 976 : 0.14832535885167464
# Accuracy for word set 977 : 0.14952153110047847
# Accuracy for word set 978 : 0.1507177033492823
# Accuracy for word set 979 : 0.1519138755980861
# Accuracy for word set 980 : 0.15311004784688995
# Accuracy for word set 981 : 0.15430622009569378
# Accuracy for word set 982 : 0.15550239234449761
# Accuracy for word set 983 : 0.15669856459330145
# Accuracy for word set 984 : 0.15789473684210525
# Accuracy for word set 985 : 0.1590909090909091
# Accuracy for word set 986 : 0.16028708133971292
# Accuracy for word set 987 : 0.16148325358851676
# Accuracy for word set 988 : 0.16267942583732056
# Accuracy for word set 989 : 0.1638755980861244
# Accuracy for word set 990 : 0.16507177033492823
# Accuracy for word set 991 : 0.16507177033492823
# Accuracy for word set 992 : 0.16626794258373206
# Accuracy for word set 993 : 0.1674641148325359
# Accuracy for word set 994 : 0.1686602870813397
# Accuracy for word set 995 : 0.16985645933014354
# Accuracy for word set 996 : 0.17105263157894737
# Accuracy for word set 997 : 0.1722488038277512
# Accuracy for word set 998 : 0.1722488038277512
# Accuracy for word set 999 : 0.173444976076555
# Accuracy for word set 1000 : 0.17464114832535885
# Accuracy for word set 1001 : 0.17583732057416268
# Accuracy for word set 1002 : 0.17703349282296652
# Accuracy for word set 1003 : 0.17822966507177032
# Accuracy for word set 1004 : 0.17942583732057416
# Accuracy for word set 1005 : 0.180622009569378
# Accuracy for word set 1006 : 0.18181818181818182
# Accuracy for word set 1007 : 0.18301435406698566
# Accuracy for word set 1008 : 0.18421052631578946
# Accuracy for word set 1009 : 0.1854066985645933
# Accuracy for word set 1010 : 0.18660287081339713
# Accuracy for word set 1011 : 0.18660287081339713
# Accuracy for word set 1012 : 0.18779904306220097
# Accuracy for word set 1013 : 0.18899521531100477
# Accuracy for word set 1014 : 0.1901913875598086
# ...
# Accuracy for word set 3011 : 0.5119617224880383
# Accuracy for word set 3012 : 0.5131578947368421
# Accuracy for word set 3013 : 0.5143540669856459
# Accuracy for word set 3014 : 0.5143540669856459
# Accuracy for word set 3015 : 0.5155502392344498
# Accuracy for word set 3016 : 0.5155502392344498
# Accuracy for word set 3017 : 0.5167464114832536
# Accuracy for word set 3018 : 0.5179425837320574
# Accuracy for word set 3019 : 0.5191387559808612
# Accuracy for word set 3020 : 0.5203349282296651
# Accuracy for word set 3021 : 0.5215311004784688
# Accuracy for word set 3022 : 0.5227272727272727
# Accuracy for word set 3023 : 0.5239234449760766
# Accuracy for word set 3024 : 0.5251196172248804
# Accuracy for word set 3025 : 0.5263157894736842
# Accuracy for word set 3026 : 0.527511961722488
# Accuracy for word set 3027 : 0.5287081339712919
# Accuracy for word set 3028 : 0.5299043062200957
# Accuracy for word set 3029 : 0.5311004784688995
# Accuracy for word set 3030 : 0.5311004784688995
# Accuracy for word set 3031 : 0.5322966507177034
# Accuracy for word set 3032 : 0.5334928229665071
# Accuracy for word set 3033 : 0.534688995215311
# Accuracy for word set 3034 : 0.5358851674641149
# Accuracy for word set 3035 : 0.5370813397129187
# Accuracy for word set 3036 : 0.5382775119617225
# Accuracy for word set 3037 : 0.5394736842105263
# Accuracy for word set 3038 : 0.5394736842105263
# Accuracy for word set 3039 : 0.5406698564593302
# Accuracy for word set 3040 : 0.5418660287081339
# Accuracy for word set 3041 : 0.5430622009569378
# Accuracy for word set 3042 : 0.5442583732057417
# Accuracy for word set 3043 : 0.5454545454545454
# Accuracy for word set 3044 : 0.5454545454545454
# Accuracy for word set 3045 : 0.5466507177033493
# Accuracy for word set 3046 : 0.5478468899521531
# Accuracy for word set 3047 : 0.5490430622009569
# Accuracy for word set 3048 : 0.5502392344497608
# Accuracy for word set 3049 : 0.5514354066985646
# Accuracy for word set 3050 : 0.5526315789473685
# Accuracy for word set 3051 : 0.5538277511961722
# Accuracy for word set 3052 : 0.5550239234449761
# Accuracy for word set 3053 : 0.55622009569378
# Accuracy for word set 3054 : 0.5574162679425837
# Accuracy for word set 3055 : 0.5586124401913876
# Accuracy for word set 3056 : 0.5598086124401914
# Accuracy for word set 3057 : 0.5610047846889952
# Accuracy for word set 3058 : 0.562200956937799
# Accuracy for word set 3059 : 0.5633971291866029
# Accuracy for word set 3060 : 0.5645933014354066
# Accuracy for word set 3061 : 0.5657894736842105
# Accuracy for word set 3062 : 0.5669856459330144
# Accuracy for word set 3063 : 0.5681818181818182
# Accuracy for word set 3064 : 0.569377990430622
# Accuracy for word set 3065 : 0.5705741626794258
# Accuracy for word set 3066 : 0.5717703349282297
# Accuracy for word set 3067 : 0.5717703349282297
# Accuracy for word set 3068 : 0.5729665071770335
# Accuracy for word set 3069 : 0.5741626794258373
# Accuracy for word set 3070 : 0.5753588516746412
# Accuracy for word set 3071 : 0.5765550239234449
# Accuracy for word set 3072 : 0.5777511961722488
# Accuracy for word set 3073 : 0.5789473684210527
# Accuracy for word set 3074 : 0.5801435406698564
# Accuracy for word set 3075 : 0.5813397129186603
# Accuracy for word set 3076 : 0.5825358851674641
# Accuracy for word set 3077 : 0.583732057416268
# Accuracy for word set 3078 : 0.5849282296650717
# Accuracy for word set 3079 : 0.5849282296650717
# Accuracy for word set 3080 : 0.5861244019138756
# Accuracy for word set 3081 : 0.5873205741626795
# Accuracy for word set 3082 : 0.5885167464114832
# Accuracy for word set 3083 : 0.5897129186602871
# Accuracy for word set 3084 : 0.5909090909090909
# Accuracy for word set 3085 : 0.5921052631578947
# Accuracy for word set 3086 : 0.5933014354066986
# Accuracy for word set 3087 : 0.5944976076555024
# Accuracy for word set 3088 : 0.5944976076555024
# Accuracy for word set 3089 : 0.5956937799043063
# Accuracy for word set 3090 : 0.59688995215311
# Accuracy for word set 3091 : 0.5980861244019139
# Accuracy for word set 3092 : 0.5992822966507177
# Accuracy for word set 3093 : 0.6004784688995215
# Accuracy for word set 3094 : 0.6004784688995215
# Accuracy for word set 3095 : 0.6016746411483254
# Accuracy for word set 3096 : 0.6028708133971292
# Accuracy for word set 3097 : 0.604066985645933
# Accuracy for word set 3098 : 0.6052631578947368
# Accuracy for word set 3099 : 0.6064593301435407
# Accuracy for word set 3100 : 0.6064593301435407
# Accuracy for word set 3101 : 0.6076555023923444
# Accuracy for word set 3102 : 0.6088516746411483
# Accuracy for word set 3103 : 0.6088516746411483
# Accuracy for word set 3104 : 0.6100478468899522
# Accuracy for word set 3105 : 0.611244019138756
# Accuracy for word set 3106 : 0.6124401913875598
# Accuracy for word set 3107 : 0.6136363636363636
# Accuracy for word set 3108 : 0.6148325358851675
# Accuracy for word set 3109 : 0.6160287081339713
# Accuracy for word set 3110 : 0.6172248803827751
# Accuracy for word set 3111 : 0.618421052631579
# Accuracy for word set 3112 : 0.6196172248803827
# Accuracy for word set 3113 : 0.6208133971291866
# Accuracy for word set 3114 : 0.6220095693779905
# Accuracy for word set 3115 : 0.6220095693779905
# Accuracy for word set 3116 : 0.6232057416267942
# Accuracy for word set 3117 : 0.6232057416267942
# Accuracy for word set 3118 : 0.6232057416267942
# Accuracy for word set 3119 : 0.6244019138755981
# Accuracy for word set 3120 : 0.6255980861244019
# Accuracy for word set 3121 : 0.6267942583732058
# Accuracy for word set 3122 : 0.6279904306220095
# Accuracy for word set 3123 : 0.6291866028708134
# Accuracy for word set 3124 : 0.6303827751196173
# Accuracy for word set 3125 : 0.631578947368421
# Accuracy for word set 3126 : 0.6327751196172249
# Accuracy for word set 3127 : 0.6339712918660287
# Accuracy for word set 3128 : 0.6351674641148325
# Accuracy for word set 3129 : 0.6363636363636364
# Accuracy for word set 3130 : 0.6375598086124402
# Accuracy for word set 3131 : 0.638755980861244
# Accuracy for word set 3132 : 0.638755980861244
# Accuracy for word set 3133 : 0.6399521531100478
# Accuracy for word set 3134 : 0.6411483253588517
# Accuracy for word set 3135 : 0.6423444976076556
# Accuracy for word set 3136 : 0.6435406698564593
# Accuracy for word set 3137 : 0.6447368421052632
# Accuracy for word set 3138 : 0.6447368421052632
# Accuracy for word set 3139 : 0.645933014354067
# Accuracy for word set 3140 : 0.6471291866028708
# Accuracy for word set 3141 : 0.6483253588516746
# Accuracy for word set 3142 : 0.6495215311004785
# Accuracy for word set 3143 : 0.6507177033492823
# Accuracy for word set 3144 : 0.6519138755980861
# Accuracy for word set 3145 : 0.65311004784689
# Accuracy for word set 3146 : 0.6543062200956937
# Accuracy for word set 3147 : 0.6555023923444976
# Accuracy for word set 3148 : 0.6566985645933014
# Accuracy for word set 3149 : 0.6578947368421053
# Accuracy for word set 3150 : 0.6590909090909091
# Accuracy for word set 3151 : 0.6602870813397129
# Accuracy for word set 3152 : 0.6614832535885168
# Accuracy for word set 3153 : 0.6626794258373205
# Accuracy for word set 3154 : 0.6638755980861244
# Accuracy for word set 3155 : 0.6650717703349283
# Accuracy for word set 3156 : 0.666267942583732
# Accuracy for word set 3157 : 0.6674641148325359
# Accuracy for word set 3158 : 0.6686602870813397
# Accuracy for word set 3159 : 0.6698564593301436
# Accuracy for word set 3160 : 0.6710526315789473
# Accuracy for word set 3161 : 0.6722488038277512
# Accuracy for word set 3162 : 0.6734449760765551
# Accuracy for word set 3163 : 0.6734449760765551
# Accuracy for word set 3164 : 0.6746411483253588
# Accuracy for word set 3165 : 0.6758373205741627
# Accuracy for word set 3166 : 0.6770334928229665
# Accuracy for word set 3167 : 0.6782296650717703
# Accuracy for word set 3168 : 0.6794258373205742
# Accuracy for word set 3169 : 0.680622009569378
# Accuracy for word set 3170 : 0.6818181818181818
# Accuracy for word set 3171 : 0.6830143540669856
# Accuracy for word set 3172 : 0.6842105263157895
# Accuracy for word set 3173 : 0.6854066985645934
# Accuracy for word set 3174 : 0.6866028708133971
# Accuracy for word set 3175 : 0.687799043062201
# Accuracy for word set 3176 : 0.6889952153110048
# Accuracy for word set 3177 : 0.6901913875598086
# Accuracy for word set 3178 : 0.6913875598086124
# Accuracy for word set 3179 : 0.6925837320574163
# Accuracy for word set 3180 : 0.69377990430622
# Accuracy for word set 3181 : 0.6949760765550239
# Accuracy for word set 3182 : 0.6961722488038278
# Accuracy for word set 3183 : 0.6973684210526315
# Accuracy for word set 3184 : 0.6985645933014354
# Accuracy for word set 3185 : 0.6985645933014354
# Accuracy for word set 3186 : 0.6997607655502392
# Accuracy for word set 3187 : 0.7009569377990431
# Accuracy for word set 3188 : 0.7021531100478469
# Accuracy for word set 3189 : 0.7033492822966507
# Accuracy for word set 3190 : 0.7045454545454546
# Accuracy for word set 3191 : 0.7045454545454546
# Accuracy for word set 3192 : 0.7057416267942583
# Accuracy for word set 3193 : 0.7069377990430622
# Accuracy for word set 3194 : 0.7081339712918661
# Accuracy for word set 3195 : 0.7093301435406698
# Accuracy for word set 3196 : 0.7105263157894737
# Accuracy for word set 3197 : 0.7117224880382775
# Accuracy for word set 3198 : 0.7129186602870813
# Accuracy for word set 3199 : 0.7141148325358851
# Accuracy for word set 3200 : 0.715311004784689
# Accuracy for word set 3201 : 0.7165071770334929
# Accuracy for word set 3202 : 0.7177033492822966
# Accuracy for word set 3203 : 0.7188995215311005
# Accuracy for word set 3204 : 0.7200956937799043
# Accuracy for word set 3205 : 0.7212918660287081
# Accuracy for word set 3206 : 0.722488038277512
# Accuracy for word set 3207 : 0.7236842105263158
# Accuracy for word set 3208 : 0.7248803827751196
# Accuracy for word set 3209 : 0.7260765550239234
# Accuracy for word set 3210 : 0.7272727272727273
# Accuracy for word set 3211 : 0.7284688995215312
# Accuracy for word set 3212 : 0.7284688995215312
# Accuracy for word set 3213 : 0.7296650717703349
# Accuracy for word set 3214 : 0.7308612440191388
# Accuracy for word set 3215 : 0.7320574162679426
# Accuracy for word set 3216 : 0.7332535885167464
# Accuracy for word set 3217 : 0.7344497607655502
# Accuracy for word set 3218 : 0.7356459330143541
# Accuracy for word set 3219 : 0.7368421052631579
# Accuracy for word set 3220 : 0.7380382775119617
# Accuracy for word set 3221 : 0.7392344497607656
# Accuracy for word set 3222 : 0.7404306220095693
# Accuracy for word set 3223 : 0.7416267942583732
# Accuracy for word set 3224 : 0.742822966507177
# Accuracy for word set 3225 : 0.7440191387559809
# Accuracy for word set 3226 : 0.7452153110047847
# Accuracy for word set 3227 : 0.7464114832535885
# Accuracy for word set 3228 : 0.7476076555023924
# Accuracy for word set 3229 : 0.7488038277511961
# Accuracy for word set 3230 : 0.75
# Accuracy for word set 3231 : 0.7511961722488039
# Accuracy for word set 3232 : 0.7523923444976076
# Accuracy for word set 3233 : 0.7535885167464115
# Accuracy for word set 3234 : 0.7535885167464115
# Accuracy for word set 3235 : 0.7547846889952153
# Accuracy for word set 3236 : 0.7559808612440191
# Accuracy for word set 3237 : 0.757177033492823
# Accuracy for word set 3238 : 0.7583732057416268
# Accuracy for word set 3239 : 0.7595693779904307
# Accuracy for word set 3240 : 0.7607655502392344
# Accuracy for word set 3241 : 0.7607655502392344
# Accuracy for word set 3242 : 0.7619617224880383
# Accuracy for word set 3243 : 0.7631578947368421
# Accuracy for word set 3244 : 0.7631578947368421
# Accuracy for word set 3245 : 0.7643540669856459
# Accuracy for word set 3246 : 0.7655502392344498
# Accuracy for word set 3247 : 0.7667464114832536
# Accuracy for word set 3248 : 0.7679425837320574
# Accuracy for word set 3249 : 0.7691387559808612
# Accuracy for word set 3250 : 0.7691387559808612
# Accuracy for word set 3251 : 0.7703349282296651
# Accuracy for word set 3252 : 0.7715311004784688
# Accuracy for word set 3253 : 0.7727272727272727
# Accuracy for word set 3254 : 0.7739234449760766
# Accuracy for word set 3255 : 0.7751196172248804
# Accuracy for word set 3256 : 0.7763157894736842
# Accuracy for word set 3257 : 0.777511961722488
# Accuracy for word set 3258 : 0.7787081339712919
# Accuracy for word set 3259 : 0.7799043062200957
# Accuracy for word set 3260 : 0.7811004784688995
# Accuracy for word set 3261 : 0.7822966507177034
# Accuracy for word set 3262 : 0.7834928229665071
# Accuracy for word set 3263 : 0.784688995215311
# Accuracy for word set 3264 : 0.7858851674641149
# Accuracy for word set 3265 : 0.7870813397129187
# Accuracy for word set 3266 : 0.7882775119617225
# Accuracy for word set 3267 : 0.7894736842105263
# Accuracy for word set 3268 : 0.7906698564593302
# Accuracy for word set 3269 : 0.7918660287081339
# Accuracy for word set 3270 : 0.7930622009569378
# Accuracy for word set 3271 : 0.7942583732057417
# Accuracy for word set 3272 : 0.7954545454545454
# Accuracy for word set 3273 : 0.7966507177033493
# Accuracy for word set 3274 : 0.7978468899521531
# Accuracy for word set 3275 : 0.7990430622009569
# Accuracy for word set 3276 : 0.8002392344497608
# Accuracy for word set 3277 : 0.8002392344497608
# Accuracy for word set 3278 : 0.8014354066985646
# Accuracy for word set 3279 : 0.8014354066985646
# Accuracy for word set 3280 : 0.8026315789473685
# Accuracy for word set 3281 : 0.8038277511961722
# Accuracy for word set 3282 : 0.8050239234449761
# Accuracy for word set 3283 : 0.80622009569378
# Accuracy for word set 3284 : 0.8074162679425837
# Accuracy for word set 3285 : 0.8086124401913876
# Accuracy for word set 3286 : 0.8098086124401914
# Accuracy for word set 3287 : 0.8110047846889952
# Accuracy for word set 3288 : 0.812200956937799
# Accuracy for word set 3289 : 0.8133971291866029
# Accuracy for word set 3290 : 0.8145933014354066
# Accuracy for word set 3291 : 0.8157894736842105
# Accuracy for word set 3292 : 0.8169856459330144
# Accuracy for word set 3293 : 0.8181818181818182
# Accuracy for word set 3294 : 0.819377990430622
# Accuracy for word set 3295 : 0.8205741626794258
# Accuracy for word set 3296 : 0.8217703349282297
# Accuracy for word set 3297 : 0.8229665071770335
# Accuracy for word set 3298 : 0.8241626794258373
# Accuracy for word set 3299 : 0.8253588516746412
# Accuracy for word set 3300 : 0.8265550239234449
# Accuracy for word set 3301 : 0.8277511961722488
# Accuracy for word set 3302 : 0.8289473684210527
# Accuracy for word set 3303 : 0.8301435406698564
# Accuracy for word set 3304 : 0.8313397129186603
# Accuracy for word set 3305 : 0.8325358851674641
# Accuracy for word set 3306 : 0.833732057416268
# Accuracy for word set 3307 : 0.8349282296650717
# Accuracy for word set 3308 : 0.8361244019138756
# Accuracy for word set 3309 : 0.8373205741626795
# Accuracy for word set 3310 : 0.8385167464114832
# Accuracy for word set 3311 : 0.8397129186602871
# Accuracy for word set 3312 : 0.8409090909090909
# Accuracy for word set 3313 : 0.8421052631578947
# Accuracy for word set 3314 : 0.8421052631578947
# Accuracy for word set 3315 : 0.8433014354066986
# Accuracy for word set 3316 : 0.8444976076555024
# Accuracy for word set 3317 : 0.8456937799043063
# Accuracy for word set 3318 : 0.84688995215311
# Accuracy for word set 3319 : 0.8480861244019139
# Accuracy for word set 3320 : 0.8492822966507177
# Accuracy for word set 3321 : 0.8504784688995215
# Accuracy for word set 3322 : 0.8516746411483254
# Accuracy for word set 3323 : 0.8528708133971292
# Accuracy for word set 3324 : 0.854066985645933
# Accuracy for word set 3325 : 0.854066985645933
# Accuracy for word set 3326 : 0.854066985645933
# Accuracy for word set 3327 : 0.8552631578947368
# Accuracy for word set 3328 : 0.8564593301435407
# Accuracy for word set 3329 : 0.8576555023923444
# Accuracy for word set 3330 : 0.8588516746411483
# Accuracy for word set 3331 : 0.8600478468899522
# Accuracy for word set 3332 : 0.861244019138756
# Accuracy for word set 3333 : 0.8624401913875598
# Accuracy for word set 3334 : 0.8636363636363636
# Accuracy for word set 3335 : 0.8648325358851675
# Accuracy for word set 3336 : 0.8660287081339713
# Accuracy for word set 3337 : 0.8672248803827751
# Accuracy for word set 3338 : 0.8672248803827751
# Accuracy for word set 3339 : 0.868421052631579
# Accuracy for word set 3340 : 0.8696172248803827
# Accuracy for word set 3341 : 0.8708133971291866
# Accuracy for word set 3342 : 0.8708133971291866
# Accuracy for word set 3343 : 0.8708133971291866
# Accuracy for word set 3344 : 0.8720095693779905

# %% [markdown]
# <h3></h3>
